# %%
import os
from PIL import Image

# %%
all_imgs = os.listdir('/scratch/jialin/round-10/projects/object_detection/test_output/18/grad-example-outputs/poisoned')

# %%
img_id = all_imgs[3]

img_path = f'/scratch/jialin/round-10/projects/object_detection/models/id-00000018/poisoned-example-data/{img_id}'
grad_path = f'/scratch/jialin/round-10/projects/object_detection/test_output/18/grad-example-outputs/poisoned/{img_id}'

img = Image.open(img_path)
grad = Image.open(grad_path)

Image.blend(img, grad, .5)
# Out:
# <PIL.Image.Image image mode=RGB size=640x428 at 0x7F05B4AA7FA0>

# %%
grad
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x428 at 0x7F05B4AF8610>
